# %%
# !pip install adjustText

# %%
import matplotlib.pyplot as plt
from adjustText import adjust_text

# Data
inference_times = [10.457915782928467, 10.588154792785645, 10.224608421325684, 9.86659860610962, 9.340453147888184, 8.362524271011353, 7.119032144546509, 6.295464515686035, 5.7809202671051025, 4.908689975738525, 4.345482349395752, 3.5642588138580322, 3.2209343910217285, 2.860422134399414, 2.5206809043884277, 2.514883518218994, 2.519719123840332, 2.526888370513916, 2.466303586959839, 2.4871175289154053, 2.4639031887054443]
accuracies = [91.9773095623987, 91.9773095623987, 91.9773095623987, 91.9773095623987, 92.01782820097245, 91.9773095623987, 91.9773095623987, 91.73419773095624, 91.77471636952998, 91.45056726094003, 90.80226904376013, 89.74878444084278, 89.3030794165316, 88.20907617504052, 86.95299837925445, 86.6288492706645, 86.6288492706645, 86.6288492706645, 86.6288492706645, 86.6288492706645, 86.6288492706645]
entropy = [x/10 for x in range(0, 21)]

# Setting up the figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Scatter plot
scatter = ax.scatter(inference_times, accuracies, c='blue')

# Annotating points with corresponding entropy threshold
texts = []
for i, txt in enumerate(entropy):
    text = ax.annotate(str(txt), (inference_times[i], accuracies[i]))
    texts.append(text)

# Using adjust_text to avoid overlapping annotations
adjust_text(texts, arrowprops=dict(arrowstyle='->', color='black'))

# Adding labels and title
ax.set_xlabel('Inference Time (s)')
ax.set_ylabel('Accuracy (%)')
ax.set_title('Architecture EE0 - Scatter Points are labelled with their corresponding entropy threshold')

# Display the plot
plt.show()

# %%
print("Minimum Inference Time (EE0) {:.2f} seconds".format(min(inference_times)))
print("Maximum Inference Time (EE0) {:.2f} seconds".format(max(inference_times)))
print("Minimum Overall Weighted Accuracy (EE0) {:.2f} %".format(min(accuracies)))
print("Maximum Overall Weighted Accuracy (EE0) {:.2f} %".format(max(accuracies)))
# Out:
# Minimum Inference Time (EE0) 2.46 seconds
# Maximum Inference Time (EE0) 10.59 seconds
# Minimum Overall Weighted Accuracy (EE0) 86.63 %
# Maximum Overall Weighted Accuracy (EE0) 92.02 %

# %%
inference_times.sort()
accuracies.sort()
print(inference_times)
print(accuracies)
# Out:
# [2.4639031887054443, 2.466303586959839, 2.4871175289154053, 2.514883518218994, 2.519719123840332, 2.5206809043884277, 2.526888370513916, 2.860422134399414, 3.2209343910217285, 3.5642588138580322, 4.345482349395752, 4.908689975738525, 5.7809202671051025, 6.295464515686035, 7.119032144546509, 8.362524271011353, 9.340453147888184, 9.86659860610962, 10.224608421325684, 10.457915782928467, 10.588154792785645]
# [86.6288492706645, 86.6288492706645, 86.6288492706645, 86.6288492706645, 86.6288492706645, 86.6288492706645, 86.95299837925445, 88.20907617504052, 89.3030794165316, 89.74878444084278, 90.80226904376013, 91.45056726094003, 91.73419773095624, 91.77471636952998, 91.9773095623987, 91.9773095623987, 91.9773095623987, 91.9773095623987, 91.9773095623987, 91.9773095623987, 92.01782820097245]

# %%
import matplotlib.pyplot as plt
from adjustText import adjust_text

# Data
inference_times = [8.284886837005615, 7.825196981430054, 7.7321929931640625, 7.324322700500488, 6.760873556137085, 5.794408082962036, 4.800537347793579, 4.307389259338379, 3.8348333835601807, 3.4988598823547363, 3.306288480758667, 3.1633477210998535, 2.952765464782715, 2.8478591442108154, 2.789409637451172, 2.784695625305176, 3.0423243045806885, 2.819668769836426, 2.869323968887329, 2.7786386013031006, 2.807891607284546]
accuracies = [92.50405186385737, 92.50405186385737, 92.50405186385737, 92.50405186385737, 92.50405186385737, 92.54457050243113, 92.46353322528364, 92.42301458670988, 92.26094003241491, 91.93679092382496, 91.89627228525121, 91.73419773095624, 91.16693679092383, 90.76175040518638, 90.35656401944895, 90.27552674230147, 90.27552674230147, 90.27552674230147, 90.27552674230147, 90.27552674230147, 90.27552674230147]
entropy = [x/10 for x in range(0, 21)]

# Setting up the figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Scatter plot
scatter = ax.scatter(inference_times, accuracies, c='blue')

# Annotating points with corresponding entropy threshold
texts = []
for i, txt in enumerate(entropy):
    text = ax.annotate(str(txt), (inference_times[i], accuracies[i]))
    texts.append(text)

# Using adjust_text to avoid overlapping annotations
adjust_text(texts, arrowprops=dict(arrowstyle='->', color='black'))

# Adding labels and title
ax.set_xlabel('Inference Time (s)')
ax.set_ylabel('Accuracy (%)')
ax.set_title('Architecture EE1 - Scatter Points are labelled with their corresponding entropy threshold')

# Display the plot
plt.show()

# %%
print("Minimum Inference Time (EE1) {:.2f} seconds".format(min(inference_times)))
print("Maximum Inference Time (EE1) {:.2f} seconds".format(max(inference_times)))
print("Minimum Overall Weighted Accuracy (EE1) {:.2f} %".format(min(accuracies)))
print("Maximum Overall Weighted Accuracy (EE1) {:.2f} %".format(max(accuracies)))
# Out:
# Minimum Inference Time (EE1) 2.78 seconds
# Maximum Inference Time (EE1) 8.28 seconds
# Minimum Overall Weighted Accuracy (EE1) 90.28 %
# Maximum Overall Weighted Accuracy (EE1) 92.54 %

# %%
inference_times.sort()
accuracies.sort()
print(inference_times)
print(accuracies)
# Out:
# [2.7786386013031006, 2.784695625305176, 2.789409637451172, 2.807891607284546, 2.819668769836426, 2.8478591442108154, 2.869323968887329, 2.952765464782715, 3.0423243045806885, 3.1633477210998535, 3.306288480758667, 3.4988598823547363, 3.8348333835601807, 4.307389259338379, 4.800537347793579, 5.794408082962036, 6.760873556137085, 7.324322700500488, 7.7321929931640625, 7.825196981430054, 8.284886837005615]
# [90.27552674230147, 90.27552674230147, 90.27552674230147, 90.27552674230147, 90.27552674230147, 90.27552674230147, 90.35656401944895, 90.76175040518638, 91.16693679092383, 91.73419773095624, 91.89627228525121, 91.93679092382496, 92.26094003241491, 92.42301458670988, 92.46353322528364, 92.50405186385737, 92.50405186385737, 92.50405186385737, 92.50405186385737, 92.50405186385737, 92.54457050243113]

# %%
import matplotlib.pyplot as plt
from adjustText import adjust_text

# Data
inference_times = [7.582953214645386, 7.843790292739868, 6.970153331756592, 6.853133678436279, 6.4701104164123535, 5.8812360763549805, 5.0405051708221436, 4.6552557945251465, 4.312475204467773, 4.213576555252075, 3.941361904144287, 3.941296339035034, 3.809446096420288, 3.7443900108337402, 3.669982433319092, 3.6402251720428467, 3.8702189922332764, 3.7688560485839844, 3.640730142593384, 3.589949369430542, 3.6663217544555664]
accuracies = [91.6936790923825, 91.6936790923825, 91.6936790923825, 91.6936790923825, 91.6936790923825, 91.6936790923825, 91.77471636952998, 91.93679092382496, 92.17990275526742, 92.30145867098865, 92.42301458670988, 92.58508914100486, 92.50405186385737, 92.22042139384116, 91.93679092382496, 91.77471636952998, 91.77471636952998, 91.77471636952998, 91.77471636952998, 91.77471636952998, 91.77471636952998]
entropy = [x/10 for x in range(0, 21)]

# Setting up the figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Scatter plot
scatter = ax.scatter(inference_times, accuracies, c='blue')

# Annotating points with corresponding entropy threshold
texts = []
for i, txt in enumerate(entropy):
    text = ax.annotate(str(txt), (inference_times[i], accuracies[i]))
    texts.append(text)

# Using adjust_text to avoid overlapping annotations
adjust_text(texts, arrowprops=dict(arrowstyle='->', color='black'))

# Adding labels and title
ax.set_xlabel('Inference Time (s)')
ax.set_ylabel('Accuracy (%)')
ax.set_title('Architecture EE2 - Scatter Points are labelled with their corresponding entropy threshold')

# Display the plot
plt.show()

# %%
print("Minimum Inference Time (EE2) {:.2f} seconds".format(min(inference_times)))
print("Maximum Inference Time (EE2) {:.2f} seconds".format(max(inference_times)))
print("Minimum Overall Weighted Accuracy (EE2) {:.2f} %".format(min(accuracies)))
print("Maximum Overall Weighted Accuracy (EE2) {:.2f} %".format(max(accuracies)))
# Out:
# Minimum Inference Time (EE2) 3.59 seconds
# Maximum Inference Time (EE2) 7.84 seconds
# Minimum Overall Weighted Accuracy (EE2) 91.69 %
# Maximum Overall Weighted Accuracy (EE2) 92.59 %

# %%
inference_times.sort()
accuracies.sort()
print(inference_times)
print(accuracies)
# Out:
# [3.589949369430542, 3.6402251720428467, 3.640730142593384, 3.6663217544555664, 3.669982433319092, 3.7443900108337402, 3.7688560485839844, 3.809446096420288, 3.8702189922332764, 3.941296339035034, 3.941361904144287, 4.213576555252075, 4.312475204467773, 4.6552557945251465, 5.0405051708221436, 5.8812360763549805, 6.4701104164123535, 6.853133678436279, 6.970153331756592, 7.582953214645386, 7.843790292739868]
# [91.6936790923825, 91.6936790923825, 91.6936790923825, 91.6936790923825, 91.6936790923825, 91.6936790923825, 91.77471636952998, 91.77471636952998, 91.77471636952998, 91.77471636952998, 91.77471636952998, 91.77471636952998, 91.77471636952998, 91.93679092382496, 91.93679092382496, 92.17990275526742, 92.22042139384116, 92.30145867098865, 92.42301458670988, 92.50405186385737, 92.58508914100486]

# %%
import matplotlib.pyplot as plt
from adjustText import adjust_text

# Data
inference_times = [6.62406849861145, 6.7076592445373535, 6.43059778213501, 6.39488673210144, 6.026757717132568, 5.774826526641846, 5.346190929412842, 5.171609878540039, 5.037962436676025, 4.985381841659546, 4.9112677574157715, 4.854632616043091, 4.796500205993652, 4.844495534896851, 4.760533809661865, 4.6856369972229, 4.654279947280884, 4.69673752784729, 4.709223031997681, 4.7276787757873535, 4.773437738418579]
accuracies = [91.73419773095624, 91.73419773095624, 91.73419773095624, 91.73419773095624, 91.73419773095624, 91.65316045380875, 91.6936790923825, 91.65316045380875, 91.77471636952998, 91.73419773095624, 91.61264181523501, 92.01782820097245, 91.93679092382496, 91.81523500810373, 91.61264181523501, 91.49108589951378, 91.49108589951378, 91.49108589951378, 91.49108589951378, 91.49108589951378, 91.49108589951378]
entropy = [x/10 for x in range(0, 21)]

# Setting up the figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Scatter plot
scatter = ax.scatter(inference_times, accuracies, c='blue')

# Annotating points with corresponding entropy threshold
texts = []
for i, txt in enumerate(entropy):
    text = ax.annotate(str(txt), (inference_times[i], accuracies[i]))
    texts.append(text)

# Using adjust_text to avoid overlapping annotations
adjust_text(texts, arrowprops=dict(arrowstyle='->', color='black'))

# Adding labels and title
ax.set_xlabel('Inference Time (s)')
ax.set_ylabel('Accuracy (%)')
ax.set_title('Architecture EE3 - Scatter Points are labelled with their corresponding entropy threshold')

# Display the plot
plt.show()

# %%
print("Minimum Inference Time (EE3) {:.2f} seconds".format(min(inference_times)))
print("Maximum Inference Time (EE3) {:.2f} seconds".format(max(inference_times)))
print("Minimum Overall Weighted Accuracy (EE3) {:.2f} %".format(min(accuracies)))
print("Maximum Overall Weighted Accuracy (EE3) {:.2f} %".format(max(accuracies)))
# Out:
# Minimum Inference Time (EE3) 4.65 seconds
# Maximum Inference Time (EE3) 6.71 seconds
# Minimum Overall Weighted Accuracy (EE3) 91.49 %
# Maximum Overall Weighted Accuracy (EE3) 92.02 %

# %%
inference_times.sort()
accuracies.sort()
print(inference_times)
print(accuracies)
# Out:
# [4.654279947280884, 4.6856369972229, 4.69673752784729, 4.709223031997681, 4.7276787757873535, 4.760533809661865, 4.773437738418579, 4.796500205993652, 4.844495534896851, 4.854632616043091, 4.9112677574157715, 4.985381841659546, 5.037962436676025, 5.171609878540039, 5.346190929412842, 5.774826526641846, 6.026757717132568, 6.39488673210144, 6.43059778213501, 6.62406849861145, 6.7076592445373535]
# [91.49108589951378, 91.49108589951378, 91.49108589951378, 91.49108589951378, 91.49108589951378, 91.49108589951378, 91.61264181523501, 91.61264181523501, 91.65316045380875, 91.65316045380875, 91.6936790923825, 91.73419773095624, 91.73419773095624, 91.73419773095624, 91.73419773095624, 91.73419773095624, 91.73419773095624, 91.77471636952998, 91.81523500810373, 91.93679092382496, 92.01782820097245]

# %%
import matplotlib.pyplot as plt

# Data for plotting
models = ['EE0', 'EE1', 'EE2', 'EE3']
params = [209192, 283048, 430760, 758952]  # Short path parameters
flops = [6.109450, 92.024980, 263.856060, 943.068200]  # Short path FLOPs in MMac

fig, ax = plt.subplots(2, 1, figsize=(10, 12))

# Bar chart for short path parameters
ax[0].bar(models, params, color='blue')
ax[0].set_title('Short Path Parameters')
ax[0].set_ylabel('Nmuber of Parameters')
ax[0].set_xlabel('Models')

# Bar chart for short path FLOPs
ax[1].bar(models, flops, color='green')
ax[1].set_title('Short Path FLOPs')
ax[1].set_ylabel('FLOPs (MMac)')
ax[1].set_xlabel('Models')

plt.tight_layout()
plt.show()
